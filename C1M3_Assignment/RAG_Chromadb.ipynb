# %%
import chromadb
from chromadb.utils import embedding_functions
from sentence_transformers import SentenceTransformer
import numpy as np
from typing import List, Union

# Method 1: Create a custom embedding function class
class BGEEmbeddingFunction(embedding_functions.EmbeddingFunction):
    def __init__(self, model_name: str = 'BAAI/bge-base-en-v1.5'):
        self.model = SentenceTransformer(model_name)
    
    def __call__(self, input: List[str]) -> List[List[float]]:
        # Generate embeddings
        embeddings = self.model.encode(input, convert_to_tensor=False)
        # Convert numpy arrays to lists if necessary
        if isinstance(embeddings, np.ndarray):
            embeddings = embeddings.tolist()
        return embeddings

# Method 2: Using ChromaDB's SentenceTransformerEmbeddingFunction (simpler)
def create_chromadb_with_bge_embeddings():
    # Initialize ChromaDB client
    client = chromadb.Client()
    
    # Method 1: Using custom embedding function
    custom_ef = BGEEmbeddingFunction()
    
    # Method 2: Using built-in SentenceTransformerEmbeddingFunction
    sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(
        model_name="BAAI/bge-base-en-v1.5"
    )
    
    # Create collection with custom embedding function
    collection_custom = client.create_collection(
        name="my_collection_custom",
        embedding_function=custom_ef
    )
    
    # Create collection with built-in function
    collection_builtin = client.create_collection(
        name="my_collection_builtin", 
        embedding_function=sentence_transformer_ef
    )
    
    return collection_custom, collection_builtin

# Example usage
def example_usage():
    # Create collections
    collection_custom, collection_builtin = create_chromadb_with_bge_embeddings()
    
    # Sample documents
    documents = [
        "The quick brown fox jumps over the lazy dog",
        "Machine learning is a subset of artificial intelligence",
        "ChromaDB is a vector database for AI applications"
    ]
    
    ids = ["doc1", "doc2", "doc3"]
    metadatas = [
        {"source": "example1"},
        {"source": "example2"}, 
        {"source": "example3"}
    ]
    
    # Add documents to collection (embeddings will be generated automatically)
    collection_custom.add(
        documents=documents,
        metadatas=metadatas,
        ids=ids
    )
    
    # Query the collection
    results = collection_custom.query(
        query_texts=["What is machine learning?"],
        n_results=2
    )
    
    print("Query results:")
    for i, doc in enumerate(results['documents'][0]):
        print(f"{i+1}. {doc}")
        print(f"   Distance: {results['distances'][0][i]}")
        print(f"   Metadata: {results['metadatas'][0][i]}")
    
    return results

# Advanced: Custom embedding function with preprocessing
class AdvancedBGEEmbeddingFunction(embedding_functions.EmbeddingFunction):
    def __init__(self, model_name: str = 'BAAI/bge-base-en-v1.5', normalize: bool = True):
        self.model = SentenceTransformer(model_name)
        self.normalize = normalize
    
    def __call__(self, input: List[str]) -> List[List[float]]:
        # Optional: Add query prefix for better retrieval (BGE models benefit from this)
        processed_input = []
        for text in input:
            # You can add prefixes like "Represent this sentence for searching relevant passages:"
            processed_input.append(text)
        
        # Generate embeddings
        embeddings = self.model.encode(
            processed_input, 
            convert_to_tensor=False,
            normalize_embeddings=self.normalize
        )
        
        # Convert to list format
        if isinstance(embeddings, np.ndarray):
            embeddings = embeddings.tolist()
        
        return embeddings

# Example with persistent storage
def create_persistent_collection():
    # Create persistent client
    client = chromadb.PersistentClient(path="./chroma_db")
    
    # Create embedding function
    bge_ef = BGEEmbeddingFunction()
    
    # Create or get collection
    try:
        collection = client.create_collection(
            name="persistent_bge_collection",
            embedding_function=bge_ef
        )
    except Exception:
        # Collection already exists, get it
        collection = client.get_collection(
            name="persistent_bge_collection",
            embedding_function=bge_ef
        )
    
    return collection

if __name__ == "__main__":
    # Run example
    example_usage()
    
    # Create persistent collection
    persistent_collection = create_persistent_collection()
    print(f"Persistent collection created: {persistent_collection.name}")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[2], line 141
#     137     return collection
#     139 if __name__ == "__main__":
#     140     # Run example
# --> 141     example_usage()
#     143     # Create persistent collection
#     144     persistent_collection = create_persistent_collection()
#
# Cell In[2], line 50, in example_usage()
#      48 def example_usage():
#      49     # Create collections
# ---> 50     collection_custom, collection_builtin = create_chromadb_with_bge_embeddings()
#      52     # Sample documents
#      53     # Define our documents with METADATA
#      54     documents = [
#      55         "The iPhone 15 Pro features a new titanium chassis.",
#      56         "The MacBook Pro is powered by the M3 chip for incredible performance.",
#      57         "The iPad Pro has a stunning Liquid Retina XDR display.",
#      58         "Apple Watch Series 9 introduces a new double-tap gesture."
#      59     ]
#
# Cell In[2], line 34, in create_chromadb_with_bge_embeddings()
#      29 sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(
#      30     model_name="BAAI/bge-base-en-v1.5"
#      31 )
#      33 # Create collection with custom embedding function
# ---> 34 collection_custom = client.create_collection(
#      35     name="my_collection_custom",
#      36     embedding_function=custom_ef
#      37 )
#      39 # Create collection with built-in function
#      40 collection_builtin = client.create_collection(
#      41     name="my_collection_builtin",
#      42     embedding_function=sentence_transformer_ef
#      43 )
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\chromadb\api\client.py:177, in Client.create_collection(self, name, configuration, metadata, embedding_function, data_loader, get_or_create)
#     174 if embedding_function is not None and configuration_ef is None:
#     175     configuration["embedding_function"] = embedding_function
# --> 177 model = self._server.create_collection(
#     178     name=name,
#     179     metadata=metadata,
#     180     tenant=self.tenant,
#     181     database=self.database,
#     182     get_or_create=get_or_create,
#     183     configuration=configuration,
#     184 )
#     185 return Collection(
#     186     client=self._server,
#     187     model=model,
#     188     embedding_function=embedding_function,
#     189     data_loader=data_loader,
#     190 )
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\chromadb\api\rust.py:227, in RustBindingsAPI.create_collection(self, name, configuration, metadata, get_or_create, tenant, database)
#     224 else:
#     225     configuration_json_str = None
# --> 227 collection = self.bindings.create_collection(
#     228     name, configuration_json_str, metadata, get_or_create, tenant, database
#     229 )
#     230 collection_model = CollectionModel(
#     231     id=collection.id,
#     232     name=collection.name,
#    (...)    237     database=collection.database,
#     238 )
#     239 return collection_model
#
# InternalError: Collection [my_collection_custom] already exists
