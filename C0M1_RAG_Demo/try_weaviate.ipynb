# %%
import os
import weaviate
from dotenv import load_dotenv

load_dotenv()

client = weaviate.connect_to_custom(
    http_host="cappu",
    http_port=8080,
    http_secure=False,
    grpc_host="cappu",
    grpc_port=50051,
    grpc_secure=False,
    headers={
        "X-OpenAI-Api-Key": os.getenv("OPENAI_API_KEY","")  # Or any other inference API keys
    }
)
# Test the connection
print(client.is_ready())
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeout                            Traceback (most recent call last)
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\v4.py:432, in _ConnectionBase._open_connections_rest(self, auth_client_secret, colour)
#     431 try:
# --> 432     response = client.get(oidc_url)
#     433 except Exception as e:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1048 """
#    1049 Send a `GET` request.
#    1050
#    1051 **Parameters**: See `httpx.request`.
#    1052 """
# -> 1053 return self.request(
#    1054     "GET",
#    1055     url,
#    1056     params=params,
#    1057     headers=headers,
#    1058     cookies=cookies,
#    1059     auth=auth,
#    1060     follow_redirects=follow_redirects,
#    1061     timeout=timeout,
#    1062     extensions=extensions,
#    1063 )
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectTimeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# WeaviateConnectionError                   Traceback (most recent call last)
# Cell In[1], line 7
#       3 from dotenv import load_dotenv
#       5 load_dotenv()
# ----> 7 client = weaviate.connect_to_custom(
#       8     http_host="cappu",
#       9     http_port=8080,
#      10     http_secure=False,
#      11     grpc_host="cappu",
#      12     grpc_port=50051,
#      13     grpc_secure=False,
#      14     headers={
#      15         "X-OpenAI-Api-Key": os.getenv("OPENAI_API_KEY","")  # Or any other inference API keys
#      16     }
#      17 )
#      18 # Test the connection
#      19 print(client.is_ready())
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\helpers.py:347, in connect_to_custom(http_host, http_port, http_secure, grpc_host, grpc_port, grpc_secure, headers, additional_config, auth_credentials, skip_init_checks)
#     282 def connect_to_custom(
#     283     http_host: str,
#     284     http_port: int,
#    (...)    292     skip_init_checks: bool = False,
#     293 ) -> WeaviateClient:
#     294     """Connect to a Weaviate instance with custom connection parameters.
#     295
#     296     If this is not sufficient for your customization needs then instantiate a `weaviate.WeaviateClient` instance directly.
#    (...)    345         >>> # The connection is automatically closed when the context is exited.
#     346     """
# --> 347     return __connect(
#     348         WeaviateClient(
#     349             ConnectionParams.from_params(
#     350                 http_host=http_host,
#     351                 http_port=http_port,
#     352                 http_secure=http_secure,
#     353                 grpc_host=grpc_host,
#     354                 grpc_port=grpc_port,
#     355                 grpc_secure=grpc_secure,
#     356             ),
#     357             auth_client_secret=__parse_auth_credentials(auth_credentials),
#     358             additional_headers=headers,
#     359             additional_config=additional_config,
#     360             skip_init_checks=skip_init_checks,
#     361         )
#     362     )
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\helpers.py:371, in __connect(client)
#     369 except Exception as e:
#     370     client.close()
# --> 371     raise e
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\helpers.py:367, in __connect(client)
#     365 def __connect(client: WeaviateClient) -> WeaviateClient:
#     366     try:
# --> 367         client.connect()
#     368         return client
#     369     except Exception as e:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\client_executor.py:149, in _WeaviateClientExecutor.connect(self)
#     137 def connect(self) -> executor.Result[None]:
#     138     """Connect to the Weaviate instance performing all the necessary checks.
#     139
#     140     If you have specified `skip_init_checks` in the constructor then this method will not perform any runtime checks
#    (...)    147         weaviate.exceptions.UnexpectedStatusCodeError: If weaviate reports a none OK status.
#     148     """
# --> 149     return executor.execute(
#     150         response_callback=lambda _: None,
#     151         method=self._connection.connect,
#     152     )
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\executor.py:99, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      97     return resp_call
#      98 except Exception as e:
# ---> 99     return cast(T, exception_callback(e))
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\executor.py:38, in raise_exception(e)
#      37 def raise_exception(e: Exception) -> Any:
# ---> 38     raise e
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\executor.py:80, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      71 def execute(
#      72     method: SyncOrAsyncMethod[P, R],
#      73     response_callback: SyncOrAsyncCallback[R, T, A],
#    (...)     77 ) -> Union[T, Awaitable[T], Awaitable[A]]:
#      78     # wrap method call in try-except to catch exceptions for sync method
#      79     try:
# ---> 80         call = method(*args, **kwargs)
#      81         if isinstance(call, Awaitable):
#      83             async def _execute() -> T:
#      84                 # wrap await in try-except to catch exceptions for async method
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\v4.py:918, in ConnectionSync.connect(self)
#     915 if self._connected:
#     916     return None
# --> 918 self._open_connections_rest(self._auth, "sync")
#     920 # need this to get the version of weaviate for version checks and proper GRPC configuration
#     921 try:
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\weaviate\connect\v4.py:434, in _ConnectionBase._open_connections_rest(self, auth_client_secret, colour)
#     432         response = client.get(oidc_url)
#     433     except Exception as e:
# --> 434         raise WeaviateConnectionError(
#     435             f"Error: {e}. \nIs Weaviate running and reachable at {self.url}?"
#     436         )
#     437 res = self.__process_oidc_response(response, auth_client_secret, oidc_url, colour)
#     438 assert not isinstance(res, Awaitable)
#
# WeaviateConnectionError: Connection to Weaviate failed. Details: Error: timed out.
# Is Weaviate running and reachable at http://cappu:8080?

# %%
client.close()
# Test the connection
print(client.is_ready())
# Out:
# The `WeaviateClient` is closed. Run `client.connect()` to (re)connect!
# False

# %%
client.connect()
# Test the connection
print(client.is_ready())
# Out:
# True

# %%
collection = client.collections.get("bbc_collection")
collection.query.fetch_objects()

collection.query.near_text()

collection.query.re

Reranker()

# %%
from weaviate.classes.query import (
    Filter, 
    Rerank
)

# %%
Rerank()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Rerank()
#
# File d:\learning\gitea\py_demo\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for Rerank
# prop
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
